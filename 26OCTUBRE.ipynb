# %% [markdown]
# <a href="https://colab.research.google.com/github/yaretziaguilar/THC/blob/main/26OCTUBRE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints= np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints= np.array([0,250])

plt.plot(xpoints,ypoints,"o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6,5,7,2])
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,"o")
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,marker="*")
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,marker="h")
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,"H:r")
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,"H:r", ms=18)
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])
plt.plot(xpoints,ypoints,"H:k", ms=18, mec="y")
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,linestyle="dotted")
plt.show()

# %%
plt.plot(xpoints,ypoints,color= "r")
plt.show()

# %%
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints,ypoints,linewidth="15")
plt.show()

# %%
xpoints = np.array([0,6,5,7,2])
ypoints= np.array([5,9,15,2,3])

plt.plot(xpoints)
plt.plot(ypoints)
plt.show()

# %%
x1=np.array([2,5,3,8,6])
y1=np.array([7,9,3,1,2])
x2=np.array([1,8,5,3,9])
y2=np.array([2,7,4,6,5])
plt.plot(x1,y1,x2,y2)
plt.show()

# %%
x=np.array(list(range(1,100)))
y=np.array(list(range(201,300)))
plt.plot(x,y)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Titulo')
plt.show()

# %%
x=np.array(list(range(1,100)))
y=np.array(list(range(201,300)))
plt.plot(x,y)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Titulo')
plt.grid(axis='x')
plt.show()

# %%
x=np.array(list(range(1,100)))
y=np.array(list(range(201,300)))
plt.plot(x,y)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Titulo')
plt.grid(axis='y')
plt.show()

# %%
x=np.array(list(range(1,100)))
y=np.array(list(range(201,300)))
plt.plot(x,y)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Titulo')
plt.grid(color='r', linestyle='--',linewidth=0.5)
plt.show()

# %%
x= np.linspace(0,5*np.pi,1000)
coseno=np.cos(x)
seno=np.sin(x)
print(coseno)
print(seno)
# Out:
# [ 1.          0.99987639  0.99950557  0.99888765  0.99802278  0.99691116
#   0.99555308  0.99394887  0.99209893  0.99000371  0.98766373  0.98507957
#   0.98225188  0.97918134  0.97586872  0.97231483  0.96852057  0.96448685
#   0.96021469  0.95570513  0.95095929  0.94597835  0.94076354  0.93531614
#   0.9296375   0.92372903  0.91759219  0.91122849  0.90463951  0.89782688
#   0.89079227  0.88353744  0.87606417  0.86837431  0.86046977  0.85235249
#   0.84402448  0.83548781  0.82674458  0.81779696  0.80864715  0.79929742
#   0.78975008  0.78000749  0.77007206  0.75994625  0.74963255  0.73913353
#   0.72845177  0.71758991  0.70655065  0.6953367   0.68395085  0.6723959
#   0.66067472  0.6487902   0.63674529  0.62454294  0.6121862   0.5996781
#   0.58702175  0.57422026  0.56127682  0.5481946   0.53497686  0.52162686
#   0.5081479   0.4945433   0.48081644  0.46697071  0.45300953  0.43893635
#   0.42475466  0.41046795  0.39607977  0.38159366  0.36701321  0.35234202
# ...

# %%
coseno=np.cos(x)
seno=np.sin(x)
plt.plot(coseno)
plt.plot(seno)
plt.show()

# %%
coseno=np.cos(x)
seno=np.sin(x)
plt.plot(coseno)
plt.plot(seno)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Coseno y Seno ')
plt.grid(color='k', linestyle='--',linewidth=0.5)
plt.show()

# %%
def gafica(x)
coseno=np.cos(x)
seno=np.sin(x)
plt.plot(coseno)
plt.plot(seno)
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.title('Coseno y Seno ')
plt.grid(color='k', linestyle='--',linewidth=0.5)
plt.show()
 return none
