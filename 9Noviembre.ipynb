# %% [markdown]
# <a href="https://colab.research.google.com/github/yaretziaguilar/THC/blob/main/9Noviembre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

link="https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv"
code="?raw=true"
url=link+code
df=pd.read_csv(url,sep=",",index_col=1)

# %%
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 29/08/2014                    Guinea                     482
# 29/08/2014                   Nigeria                      15
# 29/08/2014              Sierra Leone                     935
# 29/08/2014                   Liberia                     322
# 05/09/2014                    Guinea                     604
# ...                              ...                     ...
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases    Boys   Girls  \
# Date
# 29/08/2014                    287.0       289.2         192.8   86.76   57.84
# ...

# %%
df.shape
# Out:
# (2484, 11)

# %%
df.head()
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014        Guinea                     482                    287.0
# 29/08/2014       Nigeria                      15                      6.0
# 29/08/2014  Sierra Leone                     935                    380.0
# 29/08/2014       Liberia                     322                    225.0
# 05/09/2014        Guinea                     604                    362.0
#
#             Male Cases  Female Cases    Boys   Girls  Adult Male  \
# Date
# 29/08/2014       289.2         192.8   86.76   57.84      173.52
# 29/08/2014         9.0           6.0    2.70    1.80        5.40
# 29/08/2014       561.0         374.0  168.30  112.20      336.60
# 29/08/2014       193.2         128.8   57.96   38.64      115.92
# 05/09/2014       362.4         241.6  108.72   72.48      217.44
#
#             Adult Female  Old Male  Old Female
# Date
# 29/08/2014        115.68     28.92       19.28
# ...

# %%
df.tail()
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 23/03/2016                   Liberia                    3151
# 23/03/2016                     Italy                       1
# 23/03/2016                   Liberia                       2
# 23/03/2016                   Nigeria                      19
# 23/03/2016  United States of America                       4
#
#             No. of confirmed deaths  Male Cases  Female Cases    Boys   Girls  \
# Date
# 23/03/2016                      NaN      1890.6        1260.4  567.18  378.12
# 23/03/2016                      NaN         0.6           0.4    0.18    0.12
# 23/03/2016                      1.0         1.2           0.8    0.36    0.24
# 23/03/2016                      7.0        11.4           7.6    3.42    2.28
# 23/03/2016                      1.0         2.4           1.6    0.72    0.48
#
#             Adult Male  Adult Female  Old Male  Old Female
# Date
# ...

# %%
SL=df[df["Country"]=="Sierra Leone"]

# %%
cuantos=df.groupby("Country").size().reset_index(name="Conteo")
cuantos
# Out:
#                     Country  Conteo
# 0                    Guinea     259
# 1                     Italy     141
# 2                   Liberia     364
# 3                      Mali     243
# 4                   Nigeria     255
# 5                   Senegal     254
# 6              Sierra Leone     259
# 7                     Spain     243
# 8            United Kingdom     221
# 9  United States of America     245

# %%
plt.pie(cuantos["Conteo"],labels=cuantos["Country"],autopct="%0.1f%%")
plt.axis("equal")
plt.title("Distribución  del ébola por países")
plt.savefig("Patel_Paises.png",dpi=300,format="png")
plt.show()

# %%
SL
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014  Sierra Leone                     935                    380.0
# 05/09/2014  Sierra Leone                    1146                    443.0
# 08/09/2014  Sierra Leone                    1234                    461.0
# 12/09/2014  Sierra Leone                    1287                    478.0
# 16/09/2014  Sierra Leone                    1464                    514.0
# ...                  ...                     ...                      ...
# 17/12/2015  Sierra Leone                    8704                   3589.0
# 22/12/2015  Sierra Leone                    8704                   3589.0
# 23/12/2015  Sierra Leone                    8704                   3589.0
# 29/12/2015  Sierra Leone                    8704                   3589.0
# 23/03/2016  Sierra Leone                    8704                   3589.0
#
#             Male Cases  Female Cases     Boys    Girls  Adult Male  \
# ...

# %%
SL.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    2
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
mean_values=SL["No. of confirmed deaths"].mean()
mean_values
# Out:
# 3104.9961089494163

# %%
SL.fillna(mean_values,inplace= True)
# Out:
# <ipython-input-12-f8103ac629e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL.fillna(mean_values,inplace= True)

# %%
SL.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    0
# Male Cases                 0
# Female Cases               0
# Boys                       0
# Girls                      0
# Adult Male                 0
# Adult Female               0
# Old Male                   0
# Old Female                 0
# dtype: int64

# %%
Dates=SL.index[0:-1:10]
NCC=SL["No. of confirmed cases"][0:-1:10]
NCD=SL["No. of confirmed deaths"][0:-1:10]

# %%
plt.plot(Dates,NCC,"*--m",ms=2,label="infectados")
plt.plot(Dates,NCD,"d--k",ms=2,label="Decesos")
plt.grid()
plt.title("Avance del ébola en Sierra Leona")
plt.xlabel("periodo de tiempo")
plt.ylabel("Casos confirmados")
plt.xticks(rotation=90,fontsize=8)
plt.legend()
plt.show()

# %%
fig=plt.figure(figsize=(12,10))
plt.plot(Dates,NCC,"*--y",ms=2,label="infectados")
plt.bar(Dates,NCC,color="yellow",alpha=0.2)
plt.plot(Dates,NCD,"d--g",ms=2,label="Decesos")
plt.bar(Dates,NCD,color="green",alpha=0.2)
plt.grid()
plt.title("Avance del ébola en Sierra Leona")
plt.xlabel("periodo de tiempo")
plt.ylabel("Casos confirmados")
plt.xticks(rotation=90,fontsize=8)
plt.savefig("Avance_de_lébola_en_SL.png",dpi=300,format="png")
plt.legend()
plt.show()

# %%
PIvsD=100*SL["No. of confirmed deaths"]/SL['No. of confirmed cases']
SL["PIvsD"]=PIvsD
# Out:
# <ipython-input-17-c7a36a9ec66e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL["PIvsD"]=PIvsD

# %%
SL.head()
# Out:
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014  Sierra Leone                     935                    380.0
# 05/09/2014  Sierra Leone                    1146                    443.0
# 08/09/2014  Sierra Leone                    1234                    461.0
# 12/09/2014  Sierra Leone                    1287                    478.0
# 16/09/2014  Sierra Leone                    1464                    514.0
#
#             Male Cases  Female Cases    Boys   Girls  Adult Male  \
# Date
# 29/08/2014       561.0         374.0  168.30  112.20      336.60
# 05/09/2014       687.6         458.4  206.28  137.52      412.56
# 08/09/2014       740.4         493.6  222.12  148.08      444.24
# 12/09/2014       772.2         514.8  231.66  154.44      463.32
# 16/09/2014       878.4         585.6  263.52  175.68      527.04
#
#             Adult Female  Old Male  Old Female      PIvsD
# Date
# ...

# %%
recuperados=((100-PIvsD)/100)*SL['No. of confirmed cases']
SL["recuperados"]=recuperados
SL.head()
# Out:
# <ipython-input-21-6a49bd63a505>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL["recuperados"]=recuperados
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014  Sierra Leone                     935                    380.0
# 05/09/2014  Sierra Leone                    1146                    443.0
# 08/09/2014  Sierra Leone                    1234                    461.0
# 12/09/2014  Sierra Leone                    1287                    478.0
# 16/09/2014  Sierra Leone                    1464                    514.0
#
#             Male Cases  Female Cases    Boys   Girls  Adult Male  \
# Date
# 29/08/2014       561.0         374.0  168.30  112.20      336.60
# ...

# %%
SL["PR"]=(100-PIvsD)
SL.head()
# Out:
# <ipython-input-27-c625bbea59b3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   SL["PR"]=(100-PIvsD)
#                  Country  No. of confirmed cases  No. of confirmed deaths  \
# Date
# 29/08/2014  Sierra Leone                     935                    380.0
# 05/09/2014  Sierra Leone                    1146                    443.0
# 08/09/2014  Sierra Leone                    1234                    461.0
# 12/09/2014  Sierra Leone                    1287                    478.0
# 16/09/2014  Sierra Leone                    1464                    514.0
#
#             Male Cases  Female Cases    Boys   Girls  Adult Male  \
# Date
# 29/08/2014       561.0         374.0  168.30  112.20      336.60
# ...

# %%
PIsvD_mean=SL["PIvsD"].mean()
PR_mean=SL["PR"].mean()
porcentajes=[PIsvD_mean,PR_mean]
etiquetas=["PIvsD","PR"]

# %%
plt.pie(porcentajes,labels=etiquetas,autopct="%0.1f%%",colors=["green","yellow"])
plt.axis("equal")
plt.title("Porcentaje de Recuperados contra Decesos")
plt.show()
