# %% [markdown]
# <a href="https://colab.research.google.com/github/yaretziaguilar/THC/blob/main/31Octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)

#plot 2:
x=np.array([0,1,2,3])
y=np.array([3,8,5,10])

plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,1,1)#elprimero filas elsegundo columnas
plt.plot(x,y)

#plot 2:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,1)
plt.plot(x,y)

#plot 2:
x=np.array([0,1,2,3])
y=np.array([3,20,15,10])

plt.subplot(2,3,2)
plt.plot(x,y)
#plot 3:
x=np.array([0,1,2,3])
y=np.array([5,8,13,17])

plt.subplot(2,3,3)
plt.plot(x,y)

#plot 4:
x=np.array([0,1,2,3])
y=np.array([30,20,50,10])

plt.subplot(2,3,4)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Entradas")

#plot 2:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("Entradas")
plt.show()

# %%
#plot 1:
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(1,2,1)
plt.plot(x,y)
plt.title("Entradas")

#plot 2:
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])

plt.subplot(1,2,2)
plt.plot(x,y)
plt.title("salida")
plt.suptitle("Graficas")
plt.show()

# %%
x= np.linspace(0,5*np.pi,1000)
coseno=np.cos(x)
seno=np.sin(x)
print(coseno)
print(seno)
# Out:
# [ 1.          0.99987639  0.99950557  0.99888765  0.99802278  0.99691116
#   0.99555308  0.99394887  0.99209893  0.99000371  0.98766373  0.98507957
#   0.98225188  0.97918134  0.97586872  0.97231483  0.96852057  0.96448685
#   0.96021469  0.95570513  0.95095929  0.94597835  0.94076354  0.93531614
#   0.9296375   0.92372903  0.91759219  0.91122849  0.90463951  0.89782688
#   0.89079227  0.88353744  0.87606417  0.86837431  0.86046977  0.85235249
#   0.84402448  0.83548781  0.82674458  0.81779696  0.80864715  0.79929742
#   0.78975008  0.78000749  0.77007206  0.75994625  0.74963255  0.73913353
#   0.72845177  0.71758991  0.70655065  0.6953367   0.68395085  0.6723959
#   0.66067472  0.6487902   0.63674529  0.62454294  0.6121862   0.5996781
#   0.58702175  0.57422026  0.56127682  0.5481946   0.53497686  0.52162686
#   0.5081479   0.4945433   0.48081644  0.46697071  0.45300953  0.43893635
#   0.42475466  0.41046795  0.39607977  0.38159366  0.36701321  0.35234202
# ...

# %%
#plot 1:
coseno=np.cos(x)

plt.plot(coseno)
plt.subplot(1,2,1)
plt.title("Coseno")
plt.show()
# Out:
# <ipython-input-41-1426cfd3a693>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,1)

# %%
#plot 1:
coseno=np.cos(x)

plt.subplot(1,2,1)
plt.plot(coseno)
plt.title("coseno")
plt.show()

# %%
x=["A","B","C"]
y=[3,5,1]
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
por=[10,20,70]
clases=["A","B","C"]
plt.pie(por,labels=clases,autopct="%0.1f%%")
plt.show()
